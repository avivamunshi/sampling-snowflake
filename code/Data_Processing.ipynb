# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# Formatting the data in the columns so they don't give us trouble when we load it into Snowflake.

# %%
import pandas as pd

# %%
data = pd.read_excel("/Users/aviva/Desktop/MSDS/quarter_4/Scalable Data Systems/Project/final_debt_data.xlsx")
data.head()
# Out:
#                   Country Name Country Code  \
# 0  Africa Eastern and Southern          AFE
# 1  Africa Eastern and Southern          AFE
# 2  Africa Eastern and Southern          AFE
# 3  Africa Eastern and Southern          AFE
# 4  Africa Eastern and Southern          AFE
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 1  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.RU.ZS   NaN
# 2  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.UR.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2013       2014       2015  \
# 0   NaN   NaN   NaN   NaN   NaN  ...  16.914625  17.392349  17.892005
# 1   NaN   NaN   NaN   NaN   NaN  ...   6.473301   6.720331   7.015917
# ...

# %%
data['Debt'] = data.loc[:, 1960:2022].sum(axis=1)

# %%
df = data.groupby(['Country Code','Country Name', 'Indicator Code','Indicator Name'])['Debt'].sum().reset_index()

# %%
df.head()
# Out:
#   Country Code Country Name     Indicator Code  \
# 0          ABW        Aruba     AG.AGR.TRAC.NO
# 1          ABW        Aruba  AG.CON.FERT.PT.ZS
# 2          ABW        Aruba     AG.CON.FERT.ZS
# 3          ABW        Aruba     AG.LND.AGRI.K2
# 4          ABW        Aruba     AG.LND.AGRI.ZS
#
#                                       Indicator Name         Debt
# 0                   Agricultural machinery, tractors     0.000000
# 1  Fertilizer consumption (% of fertilizer produc...     0.000000
# 2  Fertilizer consumption (kilograms per hectare ...   103.050000
# 3                         Agricultural land (sq. km)  1220.000000
# 4                 Agricultural land (% of land area)   677.777778

# %%
df['Indicator Name'] = df['Indicator Name'].str.replace(',', ';')
df['Country Name'] = df['Country Name'].str.replace(',', '')

# %%
df["Indicator Name"].nunique()
# Out:
# 1477

# %%
df.head()
# Out:
#   Country Code Country Name     Indicator Code  \
# 0          ABW        Aruba     AG.AGR.TRAC.NO
# 1          ABW        Aruba  AG.CON.FERT.PT.ZS
# 2          ABW        Aruba     AG.CON.FERT.ZS
# 3          ABW        Aruba     AG.LND.AGRI.K2
# 4          ABW        Aruba     AG.LND.AGRI.ZS
#
#                                       Indicator Name         Debt
# 0                   Agricultural machinery; tractors     0.000000
# 1  Fertilizer consumption (% of fertilizer produc...     0.000000
# 2  Fertilizer consumption (kilograms per hectare ...   103.050000
# 3                         Agricultural land (sq. km)  1220.000000
# 4                 Agricultural land (% of land area)   677.777778

# %%
df.to_csv('/Users/aviva/Desktop/MSDS/quarter_4/Scalable Data Systems/Project/snowflake_input_data.csv', index=False)

# %%
max_length = 0

# %%
for index, row in df.iterrows():
    # Join all columns in the row to create a single string
    row_string = ''.join(map(str, row))
    
    # Calculate the length of the concatenated string
    row_length = len(row_string)
    
    # Update max_length if the current row has a greater length
    if row_length > max_length:
        max_length = row_length

print("Max number of characters in a row across all columns:", max_length)
# Out:
# Max number of characters in a row across all columns: 225
